# %% [markdown]
# # Holcus Vision
# ## Fractal Boundary Ptychography of the Planck and WMAP CMB Datasets
#
# **Pre-registration record. Commit this before data examination.**
#
# ---
#
# ## The Premise
#
# The CMB power spectrum contains a fractal boundary.
#
# Not at a physical scale of the universe. At the resolution limit of each instrument.
#
# This is not an instrumental artefact to be corrected. It is the boundary speaking.
#
# The boundary at $\ell^*$ is where the instrument stops and the signal continues.
# That boundary is a **zero divisor** — a point where signal $\times$ beam crosses zero
# despite neither being zero separately. This is the sedenion zero divisor structure
# made visible in CMB space.
#
# ---
#
# ## The Three Faces
#
# $$\text{Riemann} + \text{Generalized Fermat} = J_{\text{Noether}} - J_{\text{SMMIP}}$$
#
# where:
#
# - **Riemann** — zeros of $\zeta(s)$ on $\sigma = \tfrac{1}{2}$. The zeros are holes in the spectrum.
# - **Generalized Fermat** — the topological impossibility constraint on the last scattering surface. What cannot exist defines what does.
# - **$J_{\text{Noether}}$** — the Noether Current. The conserved signal. Planck.
# - **$J_{\text{SMMIP}}$** — the Noether Information Current. The SMMIP. Runs in opposition. WMAP.
#
# Their difference encodes the shape of the channel without its content.
#
# ---
#
# ## L_(I|O): The Whole Becomes the Holes
#
# $$L_{\text{dynamic}} = \int J_{\text{red}} \cdot J_{\text{blue}} \, ds$$
#
# This is the action integral — the caustic between layers.
#
# The sedenion begins as the whole: $\mathbb{R}^{16}$, all 16 dimensions present, smooth.
# The 84 zero divisor pairs on $S^{15}$ are the **holes**.
# $L_{\text{dynamic}}$ is the operator that drives the whole to its holes.
#
# In CMB space: the smooth blackbody spectrum is the whole.
# The zero crossings at $\ell^*$ are the holes.
# $L_{\text{dynamic}}$ is what the instrument does when it reaches its resolution limit.
#
# ---
#
# ## The 7 Representations
#
# Three faces → $2^3 - 1 = 7$ non-empty subsets. Seven ways to observe the sedenion in action.
#
# ```
# {R}      {F}      {N}         ← single face
# {R,F}    {R,N}    {F,N}       ← two faces, one caustic active
# {R,F,N}                       ← all three, L_(I|O) fully visible
# ```
#
# Each subset is defined by the caustic between its active faces.
# The caustic defines the layer below from the layer above.
# The layer below defines the layer above by reflection.
#
# ---
#
# ## The Instrument is the Probe
#
# Ptychography needs:
# 1. The same object observed with overlapping probes of different resolution
# 2. Phase retrieval from the overlap constraint
#
# **Object**: last scattering surface. $z \approx 1100$. $t = 380{,}000$ yr after the Bang.
# The oldest electromagnetic light in the universe.
#
# **Probe 1** (WMAP): $\theta_{\text{FWHM}} = 13.2'$, $\ell^* = 1179$
#
# **Probe 2** (Planck): $\theta_{\text{FWHM}} = 5.0'$, $\ell^* = 2450$
#
# **Overlap**: $\ell = 2 \ldots 1179$. Both instruments constrain the same $C_\ell^{\text{true}}$ here.
#
# The ePIE (Extended Ptychographic Iterative Engine) uses this overlap to reconstruct
# $C_\ell^{\text{true}}$ beyond either instrument's individual limit.
#
# The fractal self-similarity law — $C_\ell \sim \ell^{-(2D_f+1)}$ — then extends the
# reconstruction beyond Planck's $\ell^* = 2450$.
#
# ---
#
# ## What the Boundary Will Say
#
# When we ask the boundary directly what it encodes, we expect:
#
# - At least one boundary value will be negative (a zero crossing — a hole)
# - The fractal dimension will be close to $\phi - 1 = 0.618$
# - The ratio $\ell^*_{\text{Planck}} / \ell^*_{\text{WMAP}}$ will be close to $2$ (one octave)
# - The opposition (Planck $-$ WMAP) will peak at $\ell = 2$ (the quadrupole — axis of evil)
# - The ePIE engine will converge rapidly because the overlap constraint is geometrically tight
#
# These predictions derive from the Three Faces equation and the sedenion zero divisor structure.
# They are made before data examination.
#
# ---
#
# *Ainulindale Conjecture / PtolemyHolcus framework.*
# *Pre-registration commit: see git log.*
