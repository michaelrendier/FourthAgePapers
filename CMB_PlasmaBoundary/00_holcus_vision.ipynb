# %% [markdown]
# # CMB Plasma Boundary — Holcus Vision
#
# **One Claim:** The 2D CMB temperature boundary has fractal dimension D_f = φ = 1.6180... at a characteristic angular scale θ* ≈ 7–10°. φ is the critical dimension separating two phases of the fractal plasma structure.
#
# **Paper:** FourthAgePapers / CMB_PlasmaBoundary
# **Engine:** `fractal_flames.py`
# **Data:** Planck 70GHz SEVEM nside=1024 · WMAP 9yr synfast from real C_l
# **Wiki:** Written last.
#
# ---
#
# ## The Physical Picture
#
# At z ≈ 1100, the universe was plasma. The last scattering surface is not a smooth shell — it is a boundary between plasma regions of slightly different temperature, density, and phase. The CMB temperature map is the 2D projection of that boundary.
#
# The boundary between hot and cold regions in the CMB temperature map is a fractal curve. It is not fractal fur. It is not fractal foam. It is **fractal plasma flame** — the same structure seen in laboratory plasma instabilities and solar corona boundaries.
#
# ## The Geometric Claim
#
# In 1D (power spectrum), the existing CMB_FractalBoundary paper established:
#
# ```
# D_f(1D spectral) = φ − 1 = 0.6180...
# ```
#
# The 2D generalisation: the fractal boundary curve embedded in the temperature map has dimension
#
# ```
# D_f(2D boundary) = φ = 1.6180...
# ```
#
# The relationship 1D → 2D is: D_f(2D) = 1 + D_f(1D) = 1 + (φ−1) = φ.
#
# φ is the fixed point of x² = x + 1. It is the unique real number whose 2D boundary dimension equals its own 1D spectral exponent plus one.
#
# ## The Experimental Programme
#
# 1. Load real CMB sky maps (Planck, WMAP)
# 2. Extract the 2D temperature zero-crossing boundary
# 3. Measure D_f by box-counting at multiple angular scales (ptychography)
# 4. Test whether D_f = φ and whether D_f is constant across scales
# 5. Report all results — confirmed and failed — in 03_results
#
# ## Part 3 (deferred)
#
# After the data is evaluated: construct the theoretical fractal boundary from H_hat_RB and compare to the measured boundary. The theoretical θ* must emerge from first principles — it cannot be fitted to the data.
#
# ---
# *One Paper. One Claim. One Engine. One set of notebooks. Wiki written last.*
