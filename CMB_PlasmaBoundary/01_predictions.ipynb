# %% [markdown]
# # CMB Plasma Boundary — Predictions
#
# **Pre-registration date:** 2026-06-17
# **Rule:** All predictions entered here BEFORE data is examined. Results — confirmed or failed — remain in the record. Failed predictions stay in the data, period, full stop.
#
# ---
#
# ## P1 — 2D Boundary Fractal Dimension
#
# **Claim:** The fractal dimension of the 2D CMB temperature zero-crossing boundary is
#
# ```
# D_f(2D) = φ = 1.6180339887...
# ```
#
# **Derivation:** The 1D spectral fractal exponent is φ−1 (established in CMB_FractalBoundary). The 2D boundary dimension of a random field with that spectral index is 1 + (φ−1) = φ. Zero free parameters — φ is derived from the sedenion opposition constraint, not fitted.
#
# **Falsification criterion:** Measure D_f by box-counting on gnomonic patches. If D_f ≠ φ at any scale, P1 is at least partially falsified.
#
# ---
#
# ## P2 — Ptychographic Scale Invariance
#
# **Claim:** D_f = φ is constant across all angular scales. The fractal boundary image is self-similar — the same at 30°, 10°, 3°, and 1° FOV.
#
# **Physical basis:** A conserved Noether current cannot run. If φ is the fixed point of the opposition constraint, D_f must be scale-invariant.
#
# **Falsification criterion:** If D_f varies significantly with angular scale, P2 is falsified.
#
# ---
#
# ## P3 — Dataset Consistency
#
# **Claim:** Planck and WMAP yield the same D_f at each angular scale, within measurement error.
#
# **Physical basis:** Both instruments measure the same last scattering surface. The fractal structure is a property of the plasma boundary, not the instrument.
#
# **Falsification criterion:** Planck and WMAP D_f differ by more than 2σ at any scale.
#
# ---
#
# ## P4 — Fractal Plasma Physical Interpretation
#
# **Claim:** The CMB temperature boundary is fractal plasma flame — the same geometric class as laboratory plasma instability boundaries and solar corona structures. It is not fractal fur (diffuse), not fractal foam (closed cells). It is filamentary flame structure.
#
# **Falsification criterion:** If the boundary morphology is topologically closed (foam) or homogeneous (fur) rather than open filamentary structures, P4 is falsified.
#
# ---
#
# ## Constants used (zero free parameters)
#
# ```python
# PHI   = (1 + sqrt(5)) / 2   # 1.6180339887...
# PHI_1 = PHI - 1              # 0.6180339887...
# ```
#
# No fitting. No renormalisation. No tuning.

# %%
import numpy as np
PHI   = (1 + np.sqrt(5)) / 2
PHI_1 = PHI - 1
print(f'φ   = {PHI:.10f}')
print(f'φ−1 = {PHI_1:.10f}')
print()
print('P1: D_f(2D boundary) =', round(PHI, 4))
print('P2: D_f constant at all angular scales')
print('P3: Planck == WMAP at each scale (within 2σ)')
print('P4: Boundary morphology = fractal plasma flame (filamentary)')
