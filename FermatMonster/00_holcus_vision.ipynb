# %% [markdown]
# # Fermat-Monster Bridge — Vision
#
# **One claim:** FLT extinction (n≥3) and Monster gap-fill (Moonshine fills Niemeier blind spot {e₁,e₁₁,e₁₅}) are the SAME algebraic constraint — sedenion zero-divisors at dim=16 — expressed in two mathematical languages.
#
# **Rule:** No renormalization. Failed predictions stay in the data.
#
# ---

# %% [markdown]
# ## The Two Theorems
#
# **Fermat's Last Theorem (proved Wiles 1995):**
# ```
# x^n + y^n = z^n  has no solutions in positive integers for n ≥ 3
# ```
# n=2 (Pythagorean triples): ABUNDANT. n≥3: EXTINCT.
#
# **Monstrous Moonshine (McKay 1979, proved Borcherds 1992):**
# ```
# j(τ) = 1/q + 744 + 196884·q + 21493760·q² + ...
# 196884 = 196883 + 1  (Monster irrep dims + trivial)
# ```
# The Monster Group's representation theory encodes the j-function. The Monster fills exactly the algebraic gap that no Niemeier root system can fill.
#
# ---

# %% [markdown]
# ## The Bridge
#
# ```
# Fermat extinction (n≥3)
#         ↕
# Elliptic curves are modular (Wiles)
#         ↕
# j(τ) = Monster graded character (McKay/Borcherds)
#         ↕
# Monster fills Niemeier gap {e₁,e₁₁,e₁₅} (MonsterSiblings, this series)
#         ↕
# ZD at dim=16 forces the gap (Niemeier constraint, algebraic theorem)
#         ↕
# ZD at dim=16 kills multiplicative norm (Hurwitz 1898)
#         ↕
# Norm failure → FLT extinction
#         ↕
# J_red × J_blue = e^{-E}  CONSERVED  (NR4, D15 paper, this series)
# ```
#
# The chain closes. FLT and Moonshine are the same theorem spoken in different languages.
#
# ---

# %% [markdown]
# ## Provenance — What Prior Papers Established
#
# **D15 Noether-Wiles (this series):**
# - NR4: J_red × J_blue = e^{-E} CONSERVED for all σ ∈ [0,1]
# - NR4: ζ(s) computes the SUM (non-conserved) — wrong object
# - NR5: 12 all-odd ZD constellations = edge set of Q₃ (3-cube)
# - NR6: Monster lives one octonion above the sedenion
# - P6: FLT n=3,4 verified extinct; CD norm fails at dim=16
#
# **MonsterSiblings (this series):**
# - P1–P3: Niemeier gap theorem proved algebraically; Monster fills exactly {e₁,e₁₁,e₁₅}
# - Full 16-element coverage: Niemeier ∪ Monster = all sedenion elements
# - Nightmare Group (conjectural next level)
#
# **This paper adds:**
# - McKay observation in sedenion language (monster irrep dims → prime sector; j-coefficients → even sector)
# - SUM vs PRODUCT split: Monster's irrep dimensions cluster in PRIME sector; j-function coefficients cluster in EVEN sector. This IS NR4 appearing in Moonshine.
# - Explicit bridge claim: ZD forces both FLT extinction AND Niemeier gap — one identity
# - Wiles = Noether: modularity theorem = Noether conservation at σ=½
#
# ---

# %% [markdown]
# ## The SUM vs PRODUCT Split in Moonshine
#
# From D15 (NR4):
# - ζ(s) = Σ n^{-s} computes the SUM → non-conserved → cannot answer WHY
# - L_(I|O) = ∫ J_red·J_blue ds computes the PRODUCT → conserved → the right object
#
# This appears DIRECTLY in Moonshine:
#
# | Object | mod 16 | Sector | Type |
# |--------|--------|--------|---------|
# | Monster irrep dims (196883, 21296876, ...) | 3, 4, ... | PRIME sector | PRODUCT objects |
# | j-function coefficients (196884, 21493760, ...) | 4, 0, ... | EVEN sector | SUM objects |
#
# The Monster's REPRESENTATIONS live in the prime sector (the ZD domain, the conserved structure).
# The j-function COEFFICIENTS (sums of representations) live in the even sector (the CD domain, the output).
#
# McKay's observation 196884 = 196883 + 1 is the transition: prime-sector irrep + trivial = even-sector coefficient.
# This IS the L_(I|O) pathway: ZD (prime/odd sector) → boundary crossing → CD (even sector).
#
# ---

# %% [markdown]
# ## Engine
#
# `engine/fermat_monster_engine.py` v0.100
#
# Functions:
# - `cd_tower_check()` — CD norm at each Cayley-Dickson step; 𝕊 norm fails (ZD verified)
# - `mckay_observation()` — McKay c₁=196884=196883+1; 744=3×248; sector mapping
# - `j_sedenion_map()` — j-coefficients mod 16 → sedenion sectors
# - `fermat_niemeier_bridge()` — B1-B4: ZD forces both FLT extinction and Niemeier gap
# - `wiles_noether_check()` — Lagrangian conservation verified; structural bridge stated
#
# ---
