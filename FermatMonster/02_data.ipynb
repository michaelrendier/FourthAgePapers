# %% [markdown]
# # Fermat-Monster Bridge — Data
#
# This paper has no observational dataset. The data is mathematical literature + engine output.
#
# ---

# %% [markdown]
# ## Sources
#
# | Source | Claim used |
# |--------|------------|
# | Hurwitz (1898) | Only normed division algebras are ℝ,ℂ,ℍ,𝕆 |
# | Wiles (1995) | Every semistable elliptic curve over ℚ is modular → FLT |
# | Taylor-Wiles (1995) | Complement to Wiles; completes the modularity argument |
# | McKay (1979) | c₁(j) = 196884 = 196883+1; Monster connection observed |
# | Conway-Norton (1979) | Monstrous Moonshine conjecture: Moonshine primes, genus-0 property |
# | Borcherds (1992) | Proof of Monstrous Moonshine; Monster VOA V^♮ |
# | Frenkel-Lepowsky-Meurman (1988) | Construction of V^♮; c=24 Monster VOA |
# | Niemeier (1973) | 24 even unimodular lattices in ℝ²⁴ |
# | Schellekens (1993) | 71 holomorphic c=24 VOAs (used in MonsterSiblings paper) |
# | Atlas of Finite Groups | Monster irrep dimensions |
# | This series: D15 | NR4 (Lagrangian conservation), NR5 (Q₃), NR6 (Monster pathway) |
# | This series: MonsterSiblings | P1-P3 (Niemeier gap theorem, Monster fill, full coverage) |
#
# ---

# %% [markdown]
# ## j-function Data
#
# ```
# j(τ) = 1/q + 744 + 196884·q + 21493760·q² + 864299970·q³ + ...
#
# Coefficient  |  Value        |  McKay decomposition
# -------------|---------------|---------------------
# c₋₁ (pole)  |  1            |  —
# c₀           |  744          |  3 × 248 = 3 × dim(E₈)
# c₁           |  196884       |  196883 + 1  (irrep₂ + trivial)
# c₂           |  21493760     |  21296876 + 196883 + 1  (irrep₂+irrep₃+trivial)
# c₃           |  864299970    |  (sum of first several irrep dims; details in Atlas)
# ```
#
# **Monster irrep dimensions (first 7, from Atlas):**
# ```
# dim₀ =       1  (trivial)
# dim₁ =  196883  (smallest non-trivial faithful rep)
# dim₂ = 21296876
# dim₃ = 842609326
# dim₄ = 18538750076
# dim₅ = 19360062527
# dim₆ = 293553734298
# ```
#
# ---

# %% [markdown]
# ## Sedenion Data (from prior papers in this series)
#
# ```
# dim=16 (sedenion 𝕊):
#   ZD pairs: 84 total
#     72 bridge (2 odd + 2 even index)
#     12 all-odd (prime-sector constellations)
#   ZD first appears at dim=16 (Cayley-Dickson step 𝕆→𝕊)
#
# 12 all-odd ZD constellations (from D15 NR1):
#   These form Q₃ edge set. Aut(Q₃) = B₃ = (ℤ/2)³⋊S₃, order 48.
#   48 = 2 × 24 = 2 × dim(Leech lattice).
#
# Niemeier gap (from MonsterSiblings P1):
#   h ≡ 1, 11, 15 mod 16 algebraically impossible for A/D/E rank-24 systems.
#   Gap elements = {e₁, e₁₁, e₁₅} ⊂ prime sector.
#
# Monster gap-fill (from MonsterSiblings P2):
#   Moonshine primes mod 16 fill {e₁, e₁₁, e₁₅} exactly:
#     e₁:  p=17
#     e₁₁: p=11, 59
#     e₁₅: p=31, 47
# ```
#
# ---

# %% [markdown]
# ## FLT Data (from D15 P6, extended here)
#
# ```
# n=2: Pythagorean triples (a,b,c), a<b<c, c≤200: 127 primitive families
# n=3: FLT solutions, c≤500: 0
# n=4: FLT solutions, c≤300: 0
# n=5: FLT solutions, c≤50:  0
#
# CD tower norms:
#   ℝ (dim=1): |ab| = |a||b|  HOLDS  (trivial)
#   ℂ (dim=2): |z₁z₂| = |z₁||z₂|  HOLDS (Hurwitz)
#   ℍ (dim=4): |q₁q₂| = |q₁||q₂|  HOLDS (Hurwitz)
#   𝕆 (dim=8): |o₁o₂| = |o₁||o₂|  HOLDS (Hurwitz, LAST)
#   𝕊 (dim=16): |ab|² < |a|²|b|²  FAILS for ZD pairs (this paper)
# ```
#
# ---
