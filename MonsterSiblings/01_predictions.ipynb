# %% [markdown]
# # Monster Siblings and the Nightmare Group — Predictions
#
# **Pre-registered before engine run.**
# **Rule:** Failed predictions stay in the data. No renormalization.
#
# ---

# %%
import sys
sys.path.insert(0, "engine")
from nightmare_engine import MOONSHINE_PRIMES, PRIME_SECTOR

D_STAR   = 0.24600
PHI      = (1 + 5**0.5) / 2
N_VOA_C24 = 71    # Schellekens count
N_NIEMEIER = 24   # Niemeier lattices (23 with roots + Leech)
C_MONSTER  = 24   # central charge of Monster VOA
C_NIGHTMARE_CANDIDATE = N_VOA_C24 * C_MONSTER  # = 1704

print(f"N_VOA_C24  = {N_VOA_C24}")
print(f"N_NIEMEIER = {N_NIEMEIER}")
print(f"C_NIGHTMARE_CANDIDATE = {C_NIGHTMARE_CANDIDATE}")
print(f"71 is prime: {all(71 % i != 0 for i in range(2, 71))}")
print(f"71 is largest Moonshine prime: {max(MOONSHINE_PRIMES) == 71}")

# %% [markdown]
# ## P1 — Niemeier gap theorem: h ≡ 1, 11, 15 mod 16 impossible
#
# No A/D/E root system with total rank 24 can have Coxeter number h ≡ 1, 11, or 15 mod 16.
#
# Predicted gap elements: **{e1, e11, e15}**
#
# This is a theorem — the engine should confirm 0 Niemeier root systems with h ≡ {1,11,15} mod 16.

# %% [markdown]
# ## P2 — Monster fills the Niemeier gap exactly
#
# The Monster Moonshine primes cover EXACTLY {e1, e11, e15} and no prime-sector element outside the Niemeier gap.
#
# Predicted:
# - Monster-exclusive prime-sector coverage = {e1, e11, e15}
# - No prime-sector element covered by Monster-only (not also Niemeier) outside {e1,e11,e15}

# %% [markdown]
# ## P3 — Full coverage: Niemeier ∪ Monster = all 16 sedenion elements
#
# Predicted: the union of Niemeier (Coxeter h mod 16) and Monster (Moonshine primes mod 16) covers all 16 sedenion indices {0,1,...,15}.
#
# No gap remains at dim=24. The Nightmare Group must therefore operate above dim=24.

# %% [markdown]
# ## P4 — Niemeier-accessible Moonshine primes correspond to pure-A Niemeier lattices
#
# Predicted: for each Moonshine prime p with (p-1) | 24, the Niemeier lattice A_{p-1}^{24/(p-1)} exists with h=p.
#
# Predicted correspondence:
# - p=3: A2^12 with h=3
# - p=5: A4^6 with h=5
# - p=7: A6^4 with h=7
# - p=13: A12^2 with h=13
#
# (p=2: A1^24 with h=2, activates e2 = even sector)

# %% [markdown]
# ## P5 — Nightmare Group lower bound
#
# The Nightmare Group N satisfies:
#
# |N| >= |Monster|^71 x 71!
#
# This bound comes from Monster wreath S71 = Monster^71 semidirect S71,
# which acts on the 71 Schellekens VOAs with one Monster automorphism per VOA.
#
# Predicted: |N| >> 10^3900
