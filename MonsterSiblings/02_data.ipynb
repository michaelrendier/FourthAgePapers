# %% [markdown]
# # Monster Siblings and the Nightmare Group — Data
#
# This paper has no observational dataset. The data is mathematical literature + engine output.
#
# ---

# %% [markdown]
# ## Sources
#
# | Source | Claim used |
# |--------|------------|
# | Schellekens (1993) | 71 holomorphic c=24 VOAs |
# | Niemeier (1973) | 24 even unimodular lattices in R^24 |
# | Conway-Sloane (1999) | 23 Niemeier root systems; Coxeter numbers |
# | Frenkel-Lepowsky-Meurman (1984/1988) | V* construction from Leech lattice; Monster = Aut(V*) |
# | Borcherds (1992) | Monstrous Moonshine proved; j-function connection |
# | Griess (1982) | Monster group constructed; |M| exact |
# | van Ekeren-Moller-Scheithauer (2017) | 71 count confirmed complete |
#
# ## Mathematical Facts Used
#
# | Fact | Status |
# |------|--------|
# | 24 Niemeier lattices exist in R^24 | ESTABLISHED |
# | 71 holomorphic c=24 VOAs exist | ESTABLISHED (Schellekens + completeness) |
# | Monster = Aut(V*), |M| = 2^46 x ... x 71 | ESTABLISHED |
# | 15 Moonshine primes = prime divisors of |M| | ESTABLISHED |
# | Niemeier root systems: equal-Coxeter + rank-24 condition | ESTABLISHED |
# | Generator gives exactly 23 Niemeier root systems | CONFIRMED by engine |
#
# ## Engine
#
# `engine/nightmare_engine.py` v0.100 — built 2026-06-17
