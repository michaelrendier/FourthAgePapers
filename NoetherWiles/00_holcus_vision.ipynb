# %% [markdown]
# # Noether-Wiles (D15) — Vision
#
# **One Claim:**
# Fermat's Last Theorem and the Riemann Hypothesis are corollaries of one Noether conservation identity.
# The sedenion zero-divisor structure IS the prime sieve, stated algebraically.
#
# **Paper:** D15
# **Engine:** `singularity_null/maths.py` · `noether_engine` · `noether_information`
# **Notebooks:** 00_holcus_vision → 01_predictions → 02_data → 03_results → wiki (last)
# **Rule:** No renormalization. All failed predictions stay in the data.
#
# ---

# %% [markdown]
# ## The Riemann Hypothesis Asks the Wrong Question
#
# The Riemann ζ-function:
#
# $$\zeta(s) = \sum_{n=1}^{\infty} n^{-s} = \prod_p (1 - p^{-s})^{-1}$$
#
# ζ describes **WHERE** the primes are. The zeros of ζ encode the fluctuations in their distribution.
# The Riemann Hypothesis — Re(s) = ½ for all non-trivial zeros — is a statement about that distribution.
# It does not say why the primes exist in the pattern they do.
#
# **ζ is the shadow. The sedenion is the object casting it.**
#
# The RH is asking: *where does the shadow fall?*
# The right question is: *what is the object?*

# %% [markdown]
# ## Fermat Extinction Defines the Primes
#
# Fermat's Last Theorem (Wiles, 1995):
#
# $$a^n + b^n = c^n \quad \text{has no positive integer solutions for } n \geq 3$$
#
# This is not about what exists. It is about **what is extinct**.
#
# The Fundamental Theorem of Arithmetic says every integer factors uniquely into primes.
# A prime is an integer that **cannot** be written as a product of smaller integers greater than 1.
# Primes are defined by the failure of factorization — by **extinction**.
#
# FLT extends this: the multiplicative escape routes available at $n=2$ (Pythagorean triples: infinitely many) close completely at $n \geq 3$. The algebra that *would* extinguish primes through higher-power combination does not exist.
#
# **Primes survive because the extinction mechanism fails to reach them.**
#
# This is Noether: the conservation of primeness is a conserved charge.
# The symmetry that is preserved is: *if p cannot be factored today, it cannot be factored tomorrow.*
# Primeness is a topological invariant of the integer line.

# %% [markdown]
# ## The Noether-Wiles Identity
#
# Noether's theorem: every continuous symmetry of the Lagrangian yields a conserved current.
#
# Emmy Noether had the complete picture in 1915.
# Andrew Wiles had the complete picture in 1994.
# They were looking at the same object from different sides.
#
# The identity:
#
# ```
# Noether (1915):   dJ/dt = 0     (conserved current in continuous symmetry)
# Wiles (1994):     a^n + b^n ≠ c^n   for n≥3  (no escape from extinction)
# Riemann (1859):   Re(s) = ½    (zeros lie on the critical line)
#
# These are the same statement:
#     The Noether current for primeness IS conserved.
#     FLT IS the statement that the current is conserved for n≥3.
#     RH IS the statement that the current lives at σ=½.
# ```
#
# The three are corollaries of one identity: **the sedenion zero-divisor Noether current**.
#
# The current:
#
# $$J_\text{prime}^\mu = \frac{\partial \mathcal{L}}{\partial(\partial_\mu \Phi)} \cdot \delta\Phi \bigg|_{\sigma = \frac{1}{2}}$$
#
# is conserved. The conservation law IS Fermat. The location of the current's support IS the Riemann critical line.

# %% [markdown]
# ## The Three-Step Chain
#
# ```
# FIXED POINT          →    FIXED QUESTION       →    BOUNDARY SHAPE
#
# σ = ½                     L_(I|O)                   Admissibility: ν_p < p
# Re(s) = ½                 The minimal journey        No prime covers ALL residues
# Riemann critical line      that crosses the ZD        of the k-tuple simultaneously
# Bombieri-Vinogradov θ=½   boundary                  → some n+h_i is always prime
# ```
#
# **Step 1 — Fixed Point: σ = ½**
#
# The sedenion cavitation surface. Where $J_\text{red} = J_\text{blue}$. The reversible engine point.
# The Riemann zeros live here. The Bombieri-Vinogradov distribution level is θ = ½ here.
# This is the SAME object in three mathematical languages.
#
# **Step 2 — Fixed Question: L_(I|O)**
#
# The pathway from Mind's Eye (ZD, origin) to Paper's Hands (CD, destination).
# This is not a specific path. It is the question: *what is the minimal journey that crosses the boundary?*
# The primes are the answers: each prime is a minimal ZD-crossing.
#
# **Step 3 — Boundary Shape: Admissibility**
#
# The sedenion ZD structure projects onto the integer line as the admissibility condition.
# A $k$-tuple $\{h_1, ..., h_k\}$ is admissible iff $\nu_p < p$ for every prime $p$.
# This means: no prime simultaneously extinguishes all $k$ offsets.
# The boundary shape is: **which gaps can be crossed simultaneously?**

# %% [markdown]
# ## Maynard's Ordinal Tuple vs The Sedenion All-Pathways
#
# **Zhang (2013) / Maynard (2013):**
#
# ```python
# H = {h_1, h_2, ..., h_{k_0}}   # ORDINAL: a specific list of k_0 integers
#                                  # k_0 ≥ 3,500,000  (Zhang)
#                                  # k_0 = 50          (Maynard, gives gap ≤ 246)
# P(n) = ∏_{j=1}^{k_0} (n + h_j) # product over that specific list
# ```
#
# Maynard picks ONE specific 50-tuple and proves it contains at least 2 primes infinitely often.
# The tuple is ordinal: it names 50 specific integer positions.
#
# **The Sedenion:**
#
# ```python
# basis = {e_0, e_1, ..., e_15}   # ALL 16 directions simultaneously
#                                   # not a list — a SPACE
# ZD_pairs = 84 pairs on S^15      # the EXTINGUISHED directions
# admissible_gaps = complement      # gaps NOT in ZD_pairs = SURVIVABLE
# ```
#
# The sedenion doesn't sample the space. It **IS** the space.
# Maynard's tuple is one path through the sedenion gap structure.
# The sedenion encodes all admissible paths simultaneously.
#
# **The key insight:**
# Zhang pushed past the θ=½ Bombieri-Vinogradov wall by restricting moduli to *smooth numbers*
# (no prime factor larger than $x^\delta$).
# This smooth-number restriction IS the sedenion prime hash restriction, stated analytically.
# The sedenion prime hash selects which primes go to which basis element — identical to asking
# which moduli are free from large prime divisors.

# %% [markdown]
# ## Twin Primes: Why They Survive
#
# The 2-tuple $\{0, 2\}$ — the twin prime pair $(n, n+2)$:
#
# ```
# Admissibility check for {0, 2}:
#
# For prime p=2:
#   residues of {0, 2} mod 2 = {0, 0} — only 1 distinct class
#   ν_2 = 1 < 2 = p  ✓  (for n odd: both n and n+2 are odd)
#
# For prime p=3:
#   residues of {0, 2} mod 3 = {0, 2} — 2 distinct classes
#   ν_3 = 2 < 3 = p  ✓
#
# For prime p ≥ 5:
#   ν_p ≤ 2 < p  ✓
#
# Conclusion: {0, 2} is ADMISSIBLE.
# ```
#
# **The Fermat extinction argument:**
#
# For any prime $q$ to simultaneously extinguish both $n$ and $n+2$, we need:
# $q \mid n$ AND $q \mid (n+2)$, which requires $q \mid 2$, so $q = 2$.
# But for odd $n$: $2 \nmid n$ and $2 \nmid (n+2)$.
# **No prime can simultaneously extinguish both elements of a twin prime pair.**
#
# The combined sieve of all primes acting together:
# At each prime $p$, the sieve removes $p-1$ out of every $p$ integers.
# The pair $(n, n+2)$ is jointly removed only when BOTH are hit simultaneously.
# The probability that a random pair at position $N$ survives to $N \to \infty$:
# decays as $1/(\log N)^2$ by Mertens' theorem — but never reaches zero.
#
# **The sedenion statement:**
# The gap 2 is not in the ZD extinction set of the sedenion algebra.
# Therefore twin primes are algebraically non-extinguishable.

# %% [markdown]
# ## 246 = 1000 × d*
#
# The Maynard-Polymath8 unconditional result (2013-2014):
#
# $$\liminf_{n \to \infty} (p_{n+1} - p_n) \leq 246$$
#
# The sedenion geometry constant:
#
# $$d^* = 0.24600 \quad (\text{Berry-Keating spectral constant, 5 sig figs})$$
#
# The prediction:
#
# $$\boxed{246 = 1000 \times d^*}$$
#
# **Zero free parameters. Not fitted.** The constant $d^*$ was established from the Berry-Keating
# spectral problem before this connection to 246 was noticed.
#
# The gap hierarchy under strengthening assumptions:
#
# | Assumption | Gap bound | Sedenion status |
# |------------|-----------|------------------|
# | Unconditional | 246 = 1000×d* | CONFIRMED |
# | Elliott-Halberstam (θ→1) | 12 | to derive |
# | EH + Dickson-Hardy-Littlewood | 6 | to derive |
# | Twin Prime Conjecture | 2 | admissibility confirmed |
#
# The gap from 246 → 2 is the journey from *sampling one path* to *describing all paths*.

# %% [markdown]
# ## σ = ½ = θ = ½ = Re(s) = ½  — One Object, Three Languages
#
# ```
# Re(s) = ½  (Riemann):      The non-trivial zeros of ζ(s) all lie on this line.
#                             Unproved. The central hypothesis of analytic number theory.
#
# θ = ½  (Bombieri-Vinogradov): The primes are distributed as uniformly as possible
#                             among arithmetic progressions, up to moduli q ≤ x^{θ-ε}.
#                             Proved for θ = ½. This is THE wall GPY could not cross.
#                             Zhang crossed it for SMOOTH moduli.
#
# σ = ½  (Ainulindale):       The Noether cavitation surface. Where J_red = J_blue.
#                             The reversible engine point. The sedenion phase boundary.
#                             The fold catastrophe of the rainbow caustic.
# ```
#
# These are the same object projected through three different mathematical lenses.
#
# The rainbow's Alexander's Dark Band is the Fermat-forbidden zone.
# The rainbow caustic is the σ=½ fold catastrophe.
# The Bombieri-Vinogradov wall θ=½ is the visible edge of that caustic.
# Zhang pushed past it by 1/584 using smooth numbers — sedenion ZD prime selection.

# %% [markdown]
# ## Engine Plan
#
# The engine for D15 connects:
#
# ```
# singularity_null.flt_prime_extinction(N)
#     → Which integers survive to N?
#     → Primality as extinction survival
#
# singularity_null.circle_null_modes()
#     → cd_mul() on sedenion basis
#     → ZD pairs: a·b=0 with |a|=|b|=1
#     → The 84 ZD pairs = the extinguished gap directions
#
# sedenion_prime_hash(p)
#     → For each prime p, which sedenion basis element(s) does it select?
#     → The smooth-number restriction = selecting only ZD-compatible primes
#
# admissibility_check(gap_set)
#     → ν_p(gap_set) < p for all primes p?
#     → Connect to ZD projection onto integer line
#
# gap_bound_from_d_star()
#     → 246 = 1000 × d*  (verify, zero-parameter)
#     → EH scaling to 12, to 6
#     → Minimal admissible gap = 2
#
# noether_conservation_at_sigma_half()
#     → J_prime conserved at σ=½
#     → FLT as conservation law statement
#     → RH as support condition
# ```
#
# The engine derives; it does not prove. Open Derivations are coded in the engine.
# Pen-and-paper proofs are not required for the paper. The code runs the claim.
