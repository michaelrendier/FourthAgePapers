# %% [markdown]
# # Noether-Wiles (D15) — Data
#
# This paper has no observational dataset. The data is mathematical literature + engine output.
#
# ---

# %% [markdown]
# ## Sources
#
# ### Primary mathematical literature
#
# | Source | Claim used | Reference |
# |--------|-----------|----------|
# | Zhang (2014) | liminf(p_{n+1}-p_n) < 7×10^7; smooth-number BV theorem | *Annals of Mathematics* 179 (2014), 1121–1174. `/tmp/zhang_bounded_gaps.pdf` |
# | Maynard (2015) | liminf(p_{n+1}-p_n) ≤ 246; 50-tuple sieve | *Annals of Mathematics* 181 (2015), 383–413 |
# | Polymath8b (2014) | Gap ≤ 246 confirmed; EH→12; strong EH→6 | *Research in the Mathematical Sciences* 1 (2014) |
# | Berry-Keating (1999) | d* = 0.24600; Witches Hat half-angle = arctan(d*) | H=xp Hamiltonian; BK spectral |
# | Wiles (1995) | FLT: a^n+b^n≠c^n for n≥3 | *Annals of Mathematics* 141 (1995), 443–551 |
# | Bombieri-Vinogradov (1965) | θ=½ distribution level for primes | Standard analytic NT reference |
# | Noether (1915) | Conservation current from Lagrangian symmetry | Standard mathematical physics |
# | Hurwitz (1898) | Only ℝ, ℂ, ℍ, 𝕆 are normed division algebras | Standard algebra reference |
#
# ### Ainulindale engine sources
#
# | Module | Used for |
# |--------|----------|
# | `singularity_null/maths.py` | cd_mul, ZD pair enumeration, flt_prime_extinction |
# | `noether_engine/algebra/cayley_dickson.py` | CD multiplication tower |
# | `noether_information/maths.py` | Noether current J_info |
# | `constants/maths.py` | d*, Ω_ZS, φ |
#
# ### Engine (this paper)
#
# `engine/noether_wiles_engine.py` — built 2026-06-17
#
# Functions:
# - `flt_prime_extinction(N)` — prime sieve + FLT numerical check
# - `sedenion_prime_hash_analysis(N)` — p mod 16 → basis element distribution
# - `admissibility_check(gap_set, max_prime)` — ν_p < p verification
# - `zd_index_differences()` — index diffs in ZD pair components
# - `gap_bound_from_d_star()` — 246 = 1000×d* verification
# - `cayley_dickson_norm_test()` — norm preservation across CD tower
#
# ---
#
# ## Pre-Engine State
#
# The following was known BEFORE running the engine:
#
# - d* = 0.24600 (from Berry-Keating, established independently)
# - Maynard/Polymath gap bound = 246 (from literature)
# - ZD pairs = 84 on S^15 (from sedenion_bridge.py, established)
# - {0,2} admissibility: analytically certain from number theory
# - FLT confirmed for n=3: proved by Euler (1770), Wiles completes all n≥3
# - CD tower norm fails at dim=16: standard sedenion algebra result
#
# The engine tests these; it does not establish them for the first time.
