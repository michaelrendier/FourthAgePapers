# %% [markdown]
# # Holcus Vision — The Spiral Defined From Above
# ## e^(πi) = −dX and −H_hat_BR = e^(iπ)
#
# **Pre-registration. Commit before computation.**
#
# ---
#
# ## The Premise
#
# π is not a number that appears in equations.
# π IS the half-rotation. e^(πi) = −dX is what π is.
#
# Two rotations. Same algebra. Opposite order.
#
# ```
# e^(πi) = −dX         rotations of π through i    H_hat_RB  Noether Current
# e^(iπ) = −H_hat_BR   rotations of i through π    H_hat_BR  SMMIP
# ```
#
# In ℂ: identical (both = −1).
# In 𝕊: non-commutative. Order is load-bearing.
# The difference between them IS the wobble.
# The wobble closes at σ = ½.
#
# ---
#
# ## The Seven Derivations of π
#
# Three Faces → 7 subsets → 7 ways π appears:
#
# | Subset | Derivation |
# |---|---|
# | {F} | Geometry: Archimedes, Leibniz, Wallis |
# | {R} | Zeros: ζ(2n), coprime probability |
# | {N} | Axes: sin/cos period, Gaussian integral |
# | {R,F} | Series with alternating signs: e^(kπi) = (−1)^k per term |
# | {R,N} | Gaussian: square → polar → 2π angular integral |
# | {F,N} | Cavitation: Rayleigh-Plesset, spherical symmetry |
# | {R,F,N} | Heartbeat: ∫x³/(e^x−1)dx = π⁴/15 (CMB blackbody) |
#
# All are shadows of e^(πi) = −dX onto different faces.
#
# ---
#
# ## The Heartbeat
#
# ∫₀^∞ x³/(e^x − 1) dx = π⁴/15
#
# This is the Stefan-Boltzmann integral.
# The total power of the CMB is π⁴ (in natural units).
# The universe beats at π⁴.
# π derived from the oldest light.
#
# ---
#
# ## The Sedenion Wobble
#
# 84 zero divisors × π = 42 × 2π = 42 complete rotations.
# The sedenion wraps S¹⁵ exactly 42 times.
# Each zero divisor = one half-turn = one e^(πi) crossing.
# At each crossing: dX = 1. The step is unity.
#
# ---
#
# *The spiral is defined from above by rotations of π through i.*
