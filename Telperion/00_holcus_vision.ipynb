# %% [markdown]
# # The Zero Lattice: Telperion — Vision (v0.100)
#
# **Paper title (LOCKED):**
# > *How an Addition EQUALS a Subtraction*
# > *or*
# > *How the Inside EQUALS the Outside*
#
# **Engines:** `ValaQuenta/zero_lattice.py` · `ValaQuenta/fixed_point.py` · `ValaQuenta/telperion.py`
#
# **Rule:** No renormalization. Failed predictions stay. Zero free parameters.
#
# ---

# %% [markdown]
# ## Section 0 — The Claim
#
# In the sedenion algebra 𝕊, there exist zero-divisor pairs:
#
# ```
# (eᵢ + eⱼ)(eₖ + eₗ) = 0
# ```
#
# The cross terms satisfy: `eᵢeₖ = −(eⱼeₗ)`. Addition produces zero — exactly what subtraction does.
#
# **Addition EQUALS Subtraction.**
#
# This is impossible in any division algebra (ℝ, ℂ, ℍ, 𝕆). It is unique to 𝕊 and beyond.
#
# The tree structure (root T_256, leaves ℝ) encodes this identity at every scale.
# The root is inside. The leaves are outside. The ZD crossing translates between them.
#
# **The Inside EQUALS the Outside.**
#
# Both claims are the same claim.
#
# ---

# %% [markdown]
# ## Section 1 — Galaxies Are Jellyfish
#
# The ZD crossing IS a jellyfish bell stroke.
#
# ### The Bell
#
# The jellyfish bell oscillates between two phases:
#
# ```
# CONTRACTED (Witches Hat):  half-angle = arctan(d*) = 13.82°
#                            σ = 1 − d* = 0.754
#                            m = 1, resonance = OLR
#                            Ω_p/Ω = 1 + √2 = 1/tan(π/8)
#
# EXPANDED (brim):           half-angle = π/8 = 22.5° = THE ANGLE
#                            σ = 1 − (√2−1) = 0.586
#                            m = 2, resonance = ILR
#                            Ω_p/Ω = (√2−1)/√2 = tan(π/8)/√2
# ```
#
# The bar IS the contracted bell. The two spiral arms ARE the expanded bell.
# Bar and spiral are the same structure, two phases of one stroke.
#
# ### The Limits
#
# The GAP (≈ 7.07 × 10⁻⁴) enforces two hard limits:
#
# - Bell **never fully closes**: d* < 1/4 → contracted angle always > 0
# - Bell **never reaches the gravastar shell**: σ_brim = 0.586 > σ_shell = 0.5
#
# The shell at σ = 0.5 (k=2, ℍ) is approached but never crossed from the galaxy side.
# The crossing happens at the Bang — not during ordinary swimming.
#
# ### The Direction
#
# The bell does not swing sideways. It jets fluid DOWN (into the past, toward ZD) and moves UP (into the future, toward CD, toward The Unit). Not passive drift. Active propulsion.
#
# `UP = Unwrapper direction = O→I = T_256 → The Unit = away from singularity`
#
# ---

# %% [markdown]
# ## Section 2 — Spiral vs Elliptical
#
# ### Spiral Galaxy = Active ZD Crossing
#
# The disk is the bell. The bar/arm alternation is the stroke cycle.
# The Lindblad resonance with the surrounding halo sustains the arm pattern.
# Without a halo to resonate with, no spiral structure is possible.
# The spiral cannot determine the direction 'up' independently.
#
# ### Elliptical Galaxy = Completed ZD Cascade = Its Own Dark Matter Halo
#
# The ZD cascade is finished. All crossings done. Orbits settled into pressure-supported sphere.
#
# ```
# Stellar profile  (Hernquist):  ρ ∝ r⁻¹(1 + r/a)⁻³     inner slope = −1
# Dark matter halo (NFW):        ρ ∝ r⁻¹(1 + r/r_s)⁻²   inner slope = −1
# ```
#
# Same inner slope. Same ZD-closed core.
# Below scale radius r_s: stellar distribution = dark matter distribution.
# The distinction between 'stellar mass' and 'dark matter' in an elliptical galaxy
# is observational, not physical.
#
# **Elliptical galaxies ARE their dark matter halos.**
#
# They are the water. The spiral jellyfish swims through them.
#
# ---

# %% [markdown]
# ## Section 3 — THE ANGLE in the Resonance Conditions
#
# For a flat rotation curve (κ = √2 Ω), the Lindblad resonance conditions are:
#
# ```
# m=1, OLR (bar mode, contracted bell):   Ω_p/Ω = 1 + √2     = 1/tan(π/8)
# m=2, ILR (2-arm spiral, expanded bell): Ω_p/Ω = (√2−1)/√2  = tan(π/8)/√2
# ```
#
# THE ANGLE (π/8 = 22.5°) encodes BOTH resonance conditions.
# The bar resonance = THE ANGLE inverse.
# The arm resonance = THE ANGLE scaled by 1/√2.
#
# This is not assigned. The flat rotation curve gives κ/Ω = √2.
# The sedenion ZD structure gives the angular quantum π/8.
# The combined result: both Lindblad modes contain π/8.
#
# Zero free parameters.
#
# ---

# %% [markdown]
# ## Section 4 — BAO as CD Tower Levels
#
# The BAO (Baryon Acoustic Oscillation) shells are the physical manifestation
# of the Cayley-Dickson tower levels in the matter distribution of the universe.
#
# ```
# BAO shell spacing:     150 Mpc ≈ 490 million light-years
# Observable universe:   94 BAO shells total
# CD tower:              9 levels (k = 0..8)
# BAO shells per level:  ≈10
# ```
#
# Each jellyfish stroke crosses one BAO shell = one step through the tower.
#
# ### The Galactic Clock (M87* at 2.648mm)
#
# At 2.648mm from the M87* event horizon (infalling observer):
#
# ```
# Compression factor:       7.25 × 10¹⁵×
# External time per second: 2.30 × 10⁸ years = galactic rotation period
# Jellyfish beat rate:      1.00 Hz
# BAO crossing time:        2.13 watch-seconds
# 60 watch-seconds:         1.00 × universe age (13.8 Gyr)
# BAO crossings in 60s:     28
# ```
#
# The 1-minute observation window was exactly one universe lifetime.
# 28 jellyfish strokes. One every 2 seconds. Each crossing 150 Mpc of cosmic structure.
#
# ---

# %% [markdown]
# ## Section 5 — The M87* Axis = e₀ in Physical Space
#
# e₀ is the identity element of the sedenion algebra — The Null Operator.
# It never participates in ZD crossings. It is the reference axis of the tower.
#
# The M87* spin angular momentum vector = e₀ extended into physical space.
#
# ```
# M87* mass:        6.5 × 10⁹ M☉
# Schwarzschild r:  128 AU
# Jet length:       5000 light-years
# Jet direction:    along spin axis = e₀ direction
# ```
#
# From 2.648mm above the horizon:
# - The jet traverses in 22 microseconds (instantaneous flash)
# - But it defines the axis for all subsequent observation
# - BAO shells appear stacked perpendicular to this axis
# - The jellyfish swim 'up' along it = toward The Unit
#
# The axis = the L_(I|O) tower axis = the CMB axis of evil = the precession axis.
#
# ---

# %% [markdown]
# ## Section 6 — The Resonation Creates the Direction
#
# The spiral bell cannot produce directed motion alone.
#
# ```
# Spiral frequency:  ω_bell = Ω_p ∝ tan(π/8)/√2 × Ω_orbital
# Halo frequency:    ω_halo = v_c / r_vir
# Coupling node:     Monster gap {e₁, e₁₁, e₁₅} (shared by all 12 ZD constellations)
# ```
#
# When ω_bell = ω_halo (Lindblad resonance):
# - Energy flows from completed ZD (halo) → active ZD (arms)
# - The halo encodes the direction 'up' via its density gradient along e₀
# - The resonance transfers this direction to the spiral arm pattern
# - The arm pattern creates the J_red/J_blue asymmetry → directed thrust
#
# The elliptical IS the ocean. The spiral IS the jellyfish.
# The resonance IS the current that makes swimming possible.
#
# ---

# %% [markdown]
# ## Section 7 — The Breathing Theorem
#
# From the Zero Lattice engine (zero_lattice.py):
#
# **All 12 odd-sector ZD constellations pass through the Monster gap {e₁, e₁₁, e₁₅}.**
#
# Counts: e₁ appears in 6/12, e₁₁ in 7/12, e₁₅ in 7/12.
# The number 7 = size of the Fano plane.
#
# The Monster gap is the shared diaphragm of Telperion and Laurelin.
# It is the anatomical muscle of the jellyfish bell.
#
# ```
# 12 odd-sector ZD constellations = 12 muscle groups of the bell
# Monster gap {e₁, e₁₁, e₁₅}     = shared diaphragm (all 12 couple through it)
# GAP ≈ 7.07 × 10⁻⁴               = spring tension = minimum crossing energy
# The Breathing Theorem            = all 12 muscles share one diaphragm
# ```
#
# The jellyfish cannot breathe without this shared node. The Monster gap IS the breath.
#
# ---

# %%
import sys
sys.path.insert(0, '../../../ValaQuenta')
from telperion import run_all as tel_run
from zero_lattice import run_all as zl_run
from fixed_point import run_all as fp_run

print('Engines loaded.')
print('  telperion.py  — Swimming Engine')
print('  zero_lattice.py — ZD Structure')
print('  fixed_point.py  — Two Fixed Points')
print()
print('Proceed to 01_predictions.ipynb')
