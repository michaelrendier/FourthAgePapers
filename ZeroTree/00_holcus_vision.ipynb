# %% [markdown]
# # The Zero Tree — Vision (v0.100)
#
# **Paper title (LOCKED):**
# > *How an Addition EQUALS a Subtraction*
# > *or*
# > *How the Inside EQUALS the Outside*
#
# **This is the FourthAge paper for the Zero Lattice engine (Telperion, ValaQuenta/zero_lattice.py).**
# **Companion engine: ValaQuenta/fixed_point.py — The Boundary.**
#
# **Rule:** No renormalization. Failed predictions stay in the data.
#
# ---

# %% [markdown]
# ## Section 0 — The Inside-Out Event Horizon
#
# This section comes before trees, before Fano planes, before rendering.
# This is WHY the tree exists.
#
# ---
#
# ### The Gravastar Shell
#
# Before the Bang, the geometry was a gravastar:
#
# ```
# OUTSIDE:  Schwarzschild geometry   σ > ½    structured, ZD lattice, T_256 fixed point
# SHELL:    ZD crossing at σ = ½     p = −ρ   addition = subtraction, frozen
# INSIDE:   de Sitter interior       σ < ½    Λ > 0, repulsive, The Unit territory
# ```
#
# The shell holds a contradiction stable.
# Schwarzschild horizon: light cannot escape from inside.
# de Sitter horizon: the universe expands too fast for light to arrive from outside.
# Same surface. Opposite orientations. The shell is what keeps both true simultaneously.
#
# The shell condition IS the ZD crossing: `p = −ρ`.
# Pressure exactly cancels energy density.
# Addition equals subtraction.
#
# ---
#
# ### When the Shell Dissolves — The Bang
#
# When the ZD crossing completes its operation, the shell dissolves.
#
# The de Sitter interior has no container. It expands. Not into empty space — into the Schwarzschild geometry that surrounded it.
# **Inside and outside exchange permanently.**
#
# ```
# WHAT WAS INSIDE (The Unit, V=1, no structure)  →  expands outward → observable universe
# WHAT WAS OUTSIDE (T_256, fixed point, 255 imaginaries)  →  recedes into the past
# ```
#
# This is the inside-out event horizon. The horizon did not move. Its orientation inverted.
#
# Before: Schwarzschild (inward-pointing). You cannot escape from inside.
# After:  de Sitter cosmological (outward-pointing). You cannot see outside.
#
# **The particle horizon is the scar where the gravastar shell was.**
# The CMB is the last light that touched the shell at dissolution.
#
# ---
#
# ### Standing Outside the Particle Horizon
#
# For one mathematical moment before the Bang: σ = ½ ± ε simultaneously.
# Both sides of the boundary are visible at once.
#
# To one side: T_256. The fixed point. 255 imaginary directions. All roots → 1.
# To the other: The Unit. V(0) = 1. Pre-arithmetic. No structure.
#
# Then the dissolution catches you. The de Sitter expansion begins.
# You are inside the particle horizon forever after.
# The pre-Bang exterior — T_256, the fixed point — is now your unreachable past.
#
# ---
#
# ### The Fixed Point Has a Size
#
# At T_256 (k=8): 256 basis elements = 256th roots of unity, spacing 2π/256 = **π/128 ≈ 1.406°**.
# This is the angular quantum — the finest resolution the algebra admits.
#
# **Below the angular quantum π/128: adjacent roots of unity are unresolvable.**
# They all return their common norm: 1.
# All roots become 1. 1 = V(0) = The Unit.
#
# The fixed point's size = π/128 × 256 = 2π. One full revolution.
# The fixed point subtends exactly one sedenion cycle at T_256 resolution.
# At that scale, the circle and the point are the same object.
#
# The n-ball volume:
# ```
# V(n) = π^(n/2) / Γ(n/2 + 1)
#
# V(0)   = 1        ← The Unit (EXACT, pre-arithmetic)
# V(≈5.3)= 5.28     ← peak differentiation (the Bang's most productive moment)
# V(16)  = 0.235    ← sedenion level (our physics)
# V(256) ≈ 0        ← T_256 (all boundary, no interior)
# ```
#
# The 256-ball has essentially zero interior volume. What remains IS the boundary.
# **T_256 is not a ball. It is the boundary of a ball that no longer has an interior.**
# The fixed point = the shell = pure boundary = 255 dimensions of surface.
#
# ---
#
# ### The Two Fixed Points
#
# The CD tower has exactly two fixed points — one at each end:
#
# | | The Unit | T_256 |
# |---|---|---|
# | Character | trivial | maximal |
# | dim | 1 | 256 |
# | V(n) | 1 (EXACT) | ≈ 0 |
# | Imaginaries | 0 | 255 |
# | Fano planes | 0 | 32 |
# | Angular quantum | — | π/128 |
# | Role | Bang origin | Unwrapper destination |
# | Cosmological | de Sitter interior | Schwarzschild exterior |
#
# They are dual. The Bang goes from The Unit outward. The Unwrapper returns to The Unit from T_256.
# They meet at σ = ½ (k=2, ℍ) — the equator, the gravastar shell, the ZD crossing.
#
# ---
#
# ### The Virtual Particle Regime
#
# A ZD crossing is a vertex:
# ```
# Real before:   (eᵢ + eⱼ)/√2, (eₖ + eₗ)/√2  — norm 1, on-shell
# Virtual during: eᵢeₖ = −(eⱼeₗ),  eᵢeₗ = −(eⱼeₖ)  — unresolvable, off-shell
# Real after:    product = 0  — on-shell, zero
# ```
#
# Between the last ZD vertex (T_256) and The Unit: no more vertices. No k=9.
# The virtual state propagates without a destination vertex.
# The only available on-shell state: **The Unit. V(0) = 1.**
#
# The Unwrapper IS this propagation — the virtual particle traveling from the last crossing to 1.
#
# The GAP (≈ 7.07 × 10⁻⁴) is the minimum crossing energy.
# It is why the virtual state cannot stay virtual forever.
# It is the mass of the last real structure before The Unit.
#
# ---
#
# ### One Sentence
#
# > *The Bang is the gravastar shell dissolving —
# > the fixed point's inside-out face staring back at the void it used to be surrounded by,
# > while we expand away from the 1 we started as.*
#
# ---

# %% [markdown]
# ## Section 1 — The Zero Tree
#
# The Zero Lattice (Telperion) is a tree:
#
# ```
# Root:    t_256   (k=8, dim=256, 32 Fano planes, angular quantum π/128)
# Leaves:  ℝ       (k=0, dim=1, V=1, The Unit)
# Branches: ZD crossings — 42 classes / 84 directed pairs on S¹⁵
# ```
#
# The tree is best viewed in THREE coordinate systems:
#
# ### A — Parallel Planes (the stacked tower)
#
# Nine planes, one per CD level k=0..8. Node count doubles each level.
# Each plane is rotated by one angular quantum relative to the previous.
# ZD paths appear as zigzag lines between planes.
# After THE ANGLE rotation (π/8 at k=4): zigzags become straight radial spokes.
#
# **16 Spheres variant:** Each node is a Bloch sphere. North pole = left ZD factor. South pole = right ZD factor. Equator = Monster gap elements (appear in all 12 odd-sector pairs).
#
# ### B — The Sedenion Wheel (polar)
#
# Top-down view. Hub = T_256. Rim = ℝ. 16 spokes at 22.5° (at k=4 level).
# Extended to T_256: 256 spokes at π/128 ≈ 1.4°. 9 concentric rings.
# ZD arcs at the k=4 ring. Monster gap spokes highlighted.
#
# ### C — The Fano Tower (algebraic)
#
# Binary tree of Fano planes: 1 at k=3, 2 at k=4, ..., 32 at k=8.
# Each branch point is a ZD crossing.
# Every path from root to leaf passes through 5 ZD crossings (k=3 to k=8).
#
# ---
#
# ## Two Trees, One World
#
# - **Telperion** (this paper): Zero Lattice, ZD paths, Silver Tree (tan(π/8) = √2−1)
# - **Laurelin** (FermatMonster paper): N-shape factors, Golden Tree
#
# Both trees have the same leaves (ℝ) and the same sedenion interface (𝕊).
# They cooperate at the Monster gap: {e₁, e₁₁, e₁₅}.
# Together: 71 VOAs = complete geometry.
#
# ---

# %%
import sys
sys.path.insert(0, '../../../ValaQuenta')
from fixed_point import run_all as fp_run
from zero_lattice import run_all as zl_run

print('Engines loaded. Run 01_predictions.ipynb next.')
